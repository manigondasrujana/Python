# %%
import pandas as pd

# %%
movies=pd.read_csv("D:\super datascience\P4-Movie-Ratings.csv")

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
len(movies)
# Out:
# 559

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['Film','Genre','CriticRating','AudienceRating','BudgetMillion','Year']

# %%
movies.head(1)
# Out:
#                     Film   Genre  CriticRating  AudienceRating  BudgetMillion  \
# 0  (500) Days of Summer   Comedy            87              81              8
#
#    Year
# 0  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null object
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillion     559 non-null int64
# Year              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film=movies.Film.astype('category')

# %%
movies.Genre=movies.Genre.astype('category')
movies.Year=movies.Year.astype('category')

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillion     559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#jointplots

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating')

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind='hex')

# %%
j=sns.jointplot(data=movies,x='BudgetMillion',y='AudienceRating')

# %%
m1=sns.distplot(movies.AudienceRating,bins=15)

# %%
n1=plt.hist(movies.AudienceRating,bins=15)

# %%
sns.set_style("darkgrid")
n1=plt.hist(movies.CriticRating,bins=15)

# %%
plt.hist(movies.BudgetMillion)
plt.show()

# %%
plt.hist(movies[movies.Genre=='Drama'].BudgetMillion)
plt.show()

# %%
plt.hist(movies[movies.Genre=='Action'].BudgetMillion,bins=15)
plt.hist(movies[movies.Genre=='Drama'].BudgetMillion,bins=15)
plt.hist(movies[movies.Genre=='Thriller'].BudgetMillion,bins=15)
plt.show()

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillion,\
          movies[movies.Genre=='Drama'].BudgetMillion,\
          movies[movies.Genre=='Thrille'].BudgetMillion],\
          bins=15,stacked=True)

plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1=list()
mylabels=list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].BudgetMillion)
    mylabels.append(gen)

# %%
h=plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabels)
plt.legend()
plt.show()

# %%
vi=sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',fit_reg=False,hue='Genre',size=5,aspect=1)

# %%
#KDE plot

k1= sns.kdeplot(movies.CriticRating,movies.AudienceRating)

# %%
k2= sns.kdeplot(movies.CriticRating,movies.AudienceRating,shade=True)

# %%
k3= sns.kdeplot(movies.CriticRating,movies.AudienceRating,shade=True,cmap='Reds',shade_lowest=False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#SUBPLOTS
kde1=sns.kdeplot(movies.BudgetMillion,movies.AudienceRating)

# %%
kde2=sns.kdeplot(movies.BudgetMillion,movies.CriticRating)

# %%
x,y=plt.subplots(1,2,figsize=(12,6))
kde1=sns.kdeplot(movies.BudgetMillion,movies.AudienceRating,ax=y[0])
kde2=sns.kdeplot(movies.BudgetMillion,movies.CriticRating,ax=y[1])

# %%
y
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000219EFDCEF0>,
# ...
#       dtype=object)

# %%
x,y=plt.subplots(2,2,figsize=(12,6))

# %%
x,y=plt.subplots(2,2,figsize=(12,6))
kde1=sns.kdeplot(movies.BudgetMillion,movies.AudienceRating,ax=y[0,0])

# %%
x,y=plt.subplots(2,2,figsize=(12,6))
kde1=sns.kdeplot(movies.BudgetMillion,movies.AudienceRating,ax=y[1,1])
kde2=sns.kdeplot(movies.BudgetMillion,movies.CriticRating,ax=y[1,0])

# %%
f, axes=plt.subplots(1,2,figsize=(12,6),sharex=True,sharey=True)
kde1=sns.kdeplot(movies.BudgetMillion,movies.AudienceRating,ax=axes[0])
kde2=sns.kdeplot(movies.BudgetMillion,movies.CriticRating,ax=axes[1])
kde1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
x=sns.boxplot(data=movies,x='Genre',y='CriticRating')

# %%
x=sns.violinplot(data=movies,x='Genre',y='CriticRating')

# %%
x=sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating')

# %%
x=sns.boxplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating')

# %%
#FacetGrid
g=sns.FacetGrid(movies,row="Genre",hue='Genre')

# %%
g=sns.FacetGrid(movies,row="Genre",col='Year',hue='Genre')

# %%
plt.scatter(movies.CriticRating,movies.AudienceRating)

# %%
kws=dict(s=50, linewidth=0.5, edgecolor='black')
g.map(plt.scatter,movies.CriticRating,movies.AudienceRating,**kws)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-f647715bdd2c> in <module>
#       1 kws=dict(s=50, linewidth=0.5, edecolor='black')
# ----> 2 g.map(plt.scatter,movies.CriticRating,movies.AudienceRating,**kws)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     728
#     729             # Get the current axis
# --> 730             ax = self.facet_axis(row_i, col_j)
#     731
#     732             # Decide what color to plot with
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in facet_axis(self, row_i, col_j)
#     858
#     859         # Get a reference to the axes object we want, and make it active
# --> 860         plt.sca(ax)
#     861         return ax
#     862
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in sca(ax)
#     912             m.canvas.figure.sca(ax)
#     913             return
# ...

# %%
g=sns.FacetGrid(movies,row="Genre",col='Year',hue='Genre')
kws=dict(s=50, linewidth=0.5, edecolor='black')
g=g.map(plt.scatter,movies.CriticRating,movies.AudienceRating,**kws)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-cdacab97ba58> in <module>
#       1 g=sns.FacetGrid(movies,row="Genre",col='Year',hue='Genre')
#       2 kws=dict(s=50, linewidth=0.5, edecolor='black')
# ----> 3 g=g.map(plt.scatter,movies.CriticRating,movies.AudienceRating,**kws)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     742
#     743             # Get the actual data we are going to plot with
# --> 744             plot_data = data_ijk[list(args)]
#     745             if self._dropna:
#     746                 plot_data = plot_data.dropna()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
# ...

# %%
g=sns.FacetGrid(movies,row="Genre",col='Year',hue='Genre')
kws=dict(s=50, linewidth=0.5, edecolor='black')
g=g.map(plt.scatter,movies.CriticRating,movies.AudienceRating, **kws)
g.set(xlim=(0,100),y=(0,100))
for ax in g.axes.flat:
    ax.plot((20,60),(20,60))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-16a73a76a1fc> in <module>
#       1 g=sns.FacetGrid(movies,row="Genre",col='Year',hue='Genre')
#       2 kws=dict(s=50, linewidth=0.5, edecolor='black')
# ----> 3 g=g.map(plt.scatter,movies.CriticRating,movies.AudienceRating, **kws)
#       4 g.set(xlim=(0,100),y=(0,100))
#       5 for ax in g.axes.flat:
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     742
#     743             # Get the actual data we are going to plot with
# --> 744             plot_data = data_ijk[list(args)]
#     745             if self._dropna:
#     746                 plot_data = plot_data.dropna()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
# ...

# %%
#Dashboards

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style("darkgrid")
f, axes=plt.subplots(2,2,figsize=(15,15))
kde1=sns.kdeplot(movies.BudgetMillion,movies.AudienceRating,ax=axes[0,0])
kde2=sns.kdeplot(movies.BudgetMillion,movies.CriticRating,ax=axes[0,1])
kde1.set(xlim=(-20,160))
kde2.set(xlim=(-20,160))
x=sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating',ax=axes[1,0])
k3= sns.kdeplot(movies.CriticRating,movies.AudienceRating,shade=True,cmap='Reds',shade_lowest=False,ax=axes[1,1])
plt.show()

# %%
sns.set_style("darkgrid")
f, axes=plt.subplots(2,2,figsize=(15,15))
kde1=sns.kdeplot(movies.BudgetMillion,movies.AudienceRating,ax=axes[0,0])
kde2=sns.kdeplot(movies.BudgetMillion,movies.CriticRating,ax=axes[0,1])
kde1.set(xlim=(-20,160))
kde2.set(xlim=(-20,160))
x=sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating',ax=axes[1,0])
axes[1,1].hist(movies.CriticRating,bins=15)
#k3= sns.kdeplot(movies.CriticRating,movies.AudienceRating,shade=True,cmap='Reds',shade_lowest=False,ax=axes[1,1])
plt.show()
