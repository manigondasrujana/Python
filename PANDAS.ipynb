# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %%
#DATA FRAME
d={'a':[1,2,3,4],'b':[4,5,6,7]}

# %%
d
# Out:
# {'a': [1, 2, 3, 4], 'b': [4, 5, 6, 7]}

# %%
df=pd.DataFrame(data=d)

# %%
df
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6
# 3  4  7

# %%
df.dtypes
# Out:
# a    int64
# b    int64
# dtype: object

# %%
#numpy ndarray
df2=pd.DataFrame(np.random.randint(low=0,high=10,size=(5,5)),columns=['a','b','c','d','e'])

# %%
df1=pd.DataFrame(np.random.randint(low=5,high=20,size=(3,4)),
                    columns=['x','y','z','w'])

# %%
df1
# Out:
#     x   y   z   w
# 0   9  13  14  13
# 1  16  12   6   6
# 2  10  11  15  15

# %%
df1.shape
# Out:
# (3, 4)

# %%
df1.T
# Out:
#     0   1   2
# x   9  16  10
# y  13  12  11
# z  14   6  15
# w  13   6  15

# %%
#series
#dataframes
df
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6
# 3  4  7

# %%
df2
# Out:
#    a  b  c  d  e
# 0  1  1  4  1  0
# 1  8  5  9  2  5
# 2  3  4  3  6  8
# 3  6  8  9  5  6
# 4  1  7  9  4  6

# %%
df2[['d']]
# Out:
#    d
# 0  1
# 1  2
# 2  6
# 3  5
# 4  4

# %%
df2[['a','c']]
# Out:
#    a  c
# 0  1  4
# 1  8  9
# 2  3  3
# 3  6  9
# 4  1  9

# %%
df2['x']=df2['a']*df2['c']

# %%
df2
# Out:
#    a  b  c  d  e   x
# 0  1  1  4  1  0   4
# 1  8  5  9  2  5  72
# 2  3  4  3  6  8   9
# 3  6  8  9  5  6  54
# 4  1  7  9  4  6   9

# %%
df3=df2.drop('e',axis=1)

# %%
df3
# Out:
#    a  b  c  d   x
# 0  1  1  4  1   4
# 1  8  5  9  2  72
# 2  3  4  3  6   9
# 3  6  8  9  5  54
# 4  1  7  9  4   9

# %%
df4=df2.drop(2,axis=0)

# %%
df4
# Out:
#    a  b  c  d  e   x
# 0  1  1  4  1  0   4
# 1  8  5  9  2  5  72
# 3  6  8  9  5  6  54
# 4  1  7  9  4  6   9

# %%
#loc,iloc
df2.loc[0]
# Out:
# a    1
# b    1
# c    4
# d    1
# e    0
# x    4
# Name: 0, dtype: int32

# %%
df2.loc[[1]]
# Out:
#    a  b  c  d  e   x
# 1  8  5  9  2  5  72

# %%
df4=pd.DataFrame(randn(5,4),index='A B C D E'.split(), columns='W X Y Z'.split())

# %%
df4
# Out:
#           W         X         Y         Z
# A -0.604704  0.331495 -0.522340  0.538133
# B -0.886621  0.191955  1.348198  0.826800
# C -0.998992 -0.671257 -1.014698  1.253081
# D  0.078463  0.646108  1.662264  2.312456
# E  0.797072  1.761248 -1.464302 -0.665836

# %%
df4.loc[['A']]
# Out:
#           W         X        Y         Z
# A -0.604704  0.331495 -0.52234  0.538133

# %%
df4.loc[['A','B']]
# Out:
#           W         X         Y         Z
# A -0.604704  0.331495 -0.522340  0.538133
# B -0.886621  0.191955  1.348198  0.826800

# %%
df4.loc['A','Y']
# Out:
# -0.522339694239077

# %%
df4.loc[df4['X']>0]
# Out:
#           W         X         Y         Z
# A -0.604704  0.331495 -0.522340  0.538133
# B -0.886621  0.191955  1.348198  0.826800
# D  0.078463  0.646108  1.662264  2.312456
# E  0.797072  1.761248 -1.464302 -0.665836

# %% [markdown]
# df4

# %%
df4[['X']]
# Out:
#           X
# A  0.331495
# B  0.191955
# C -0.671257
# D  0.646108
# E  1.761248

# %%
df4.loc[df4['X']>0,['X','Y']]
# Out:
#           X         Y
# A  0.331495 -0.522340
# B  0.191955  1.348198
# D  0.646108  1.662264
# E  1.761248 -1.464302

# %%
df4.loc[df4['X']>0,['Y']]
# Out:
#           Y
# A -0.522340
# B  1.348198
# D  1.662264
# E -1.464302

# %%
#iloc
df4
# Out:
#           W         X         Y         Z
# A -0.604704  0.331495 -0.522340  0.538133
# B -0.886621  0.191955  1.348198  0.826800
# C -0.998992 -0.671257 -1.014698  1.253081
# D  0.078463  0.646108  1.662264  2.312456
# E  0.797072  1.761248 -1.464302 -0.665836

# %%
df4.iloc[1]
# Out:
# W   -0.886621
# X    0.191955
# Y    1.348198
# Z    0.826800
# Name: B, dtype: float64

# %%
df4.iloc[[1]]
# Out:
#           W         X         Y       Z
# B -0.886621  0.191955  1.348198  0.8268

# %%
df3.iloc[1,2]
# Out:
# 9

# %%
df4.iloc[1,2]
# Out:
# 1.3481983457351667

# %%
df3
# Out:
#    a  b  c  d   x
# 0  1  1  4  1   4
# 1  8  5  9  2  72
# 2  3  4  3  6   9
# 3  6  8  9  5  54
# 4  1  7  9  4   9

# %%
df3[0:3]
# Out:
#    a  b  c  d   x
# 0  1  1  4  1   4
# 1  8  5  9  2  72
# 2  3  4  3  6   9

# %%
df3.iloc[:2]
# Out:
#    a  b  c  d   x
# 0  1  1  4  1   4
# 1  8  5  9  2  72

# %%
df3.iloc[:,2]
# Out:
# 0    4
# 1    9
# 2    3
# 3    9
# 4    9
# Name: c, dtype: int32

# %%
df3.iloc[:,2:]
# Out:
#    c  d   x
# 0  4  1   4
# 1  9  2  72
# 2  3  6   9
# 3  9  5  54
# 4  9  4   9

# %%
df3.iloc[3:5]
# Out:
#    a  b  c  d   x
# 3  6  8  9  5  54
# 4  1  7  9  4   9

# %%
df3.iloc[3,4]
# Out:
# 54

# %%
df3
# Out:
#    a  b  c  d   x
# 0  1  1  4  1   4
# 1  8  5  9  2  72
# 2  3  4  3  6   9
# 3  6  8  9  5  54
# 4  1  7  9  4   9

# %%
df3.iloc[:,2:]
# Out:
#    c  d   x
# 0  4  1   4
# 1  9  2  72
# 2  3  6   9
# 3  9  5  54
# 4  9  4   9

# %%
df3
# Out:
#    a  b  c  d   x
# 0  1  1  4  1   4
# 1  8  5  9  2  72
# 2  3  4  3  6   9
# 3  6  8  9  5  54
# 4  1  7  9  4   9

# %%
df3.iloc[[0,3,4],[0,2]]
# Out:
#    a  c
# 0  1  4
# 3  6  9
# 4  1  9

# %%
df4
# Out:
#           W         X         Y         Z
# A -0.604704  0.331495 -0.522340  0.538133
# B -0.886621  0.191955  1.348198  0.826800
# C -0.998992 -0.671257 -1.014698  1.253081
# D  0.078463  0.646108  1.662264  2.312456
# E  0.797072  1.761248 -1.464302 -0.665836

# %%
df4<0
# Out:
#        W      X      Y      Z
# A   True  False   True  False
# B   True  False  False  False
# C   True   True   True  False
# D  False  False  False  False
# E  False  False   True   True

# %%
df4>10
# Out:
#        W      X      Y      Z
# A  False  False  False  False
# B  False  False  False  False
# C  False  False  False  False
# D  False  False  False  False
# E  False  False  False  False

# %%
df4[df4<0]
# Out:
#           W         X         Y         Z
# A -0.604704       NaN -0.522340       NaN
# B -0.886621       NaN       NaN       NaN
# C -0.998992 -0.671257 -1.014698       NaN
# D       NaN       NaN       NaN       NaN
# E       NaN       NaN -1.464302 -0.665836

# %%
df4[df4<0][['W']]
# Out:
#           W
# A -0.604704
# B -0.886621
# C -0.998992
# D       NaN
# E       NaN

# %%
cust=pd.read_csv("D:\marlabs\Week1\Lesson3\Datasets\customers.csv")

# %%
cust.head(2)
# Out:
#    CustomerID Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1   Male   19                  15                      39
# 1           2   Male   21                  15                      81

# %%
cust.head(3)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6

# %%
cust['Gender'].head()
# Out:
# 0      Male
# 1      Male
# 2    Female
# 3    Female
# 4    Female
# Name: Gender, dtype: object

# %%
cust['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
cust['Gender'].nunique()
# Out:
# 2

# %%
#Groupby
cust.groupby(['Gender']).groups.keys()
# Out:
# dict_keys(['Female', 'Male'])

# %%
cust.groupby(['Gender'])

# %%
cust.groupby(['Gender']).groups['Female']
# Out:
# Int64Index([  2,   3,   4,   5,   6,   7,   9,  11,  12,  13,
#             ...
#             184, 186, 188, 189, 190, 191, 193, 194, 195, 196],
#            dtype='int64', length=112)

# %%
cust[cust.index==184]
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 184         185  Female   41                  99                      39

# %%
len(cust.groupby(['Gender']).groups['Female'])
# Out:
# 112

# %%
len(cust)
# Out:
# 200

# %%
cust[cust['Spending Score (1-100)']==39].groupby('Gender')['Annual Income (k$)'].mean()
# Out:
# Gender
# Female    99
# Male      15
# Name: Annual Income (k$), dtype: int64

# %%
cust[cust['Spending Score (1-100)']==39]
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 184         185  Female   41                  99                      39

# %%
cust.groupby('Gender')['Annual Income (k$)'].mean()
# Out:
# Gender
# Female    59.250000
# Male      62.227273
# Name: Annual Income (k$), dtype: float64

# %%
cust.groupby('Gender')[['Annual Income (k$)']].mean()
# Out:
#         Annual Income (k$)
# Gender
# Female           59.250000
# Male             62.227273

# %%
cust.groupby(['Gender','Age'])[['Annual Income (k$)']].mean()
# Out:
#             Annual Income (k$)
# Gender Age
# Female 18            65.000000
#        19            64.000000
#        20            26.500000
#        21            44.750000
#        22            37.000000
#        23            41.500000
#        24            29.500000
#        25            72.000000
#        27            56.000000
#        28            76.000000
#        29            72.500000
#        30            59.400000
#        31            51.714286
#        32            76.833333
#        33            86.000000
#        34            79.666667
#        35            45.833333
#        36            78.000000
#        37            97.000000
#        38            80.500000
#        40            52.666667
#        41           101.000000
#        42            34.000000
#        43            48.000000
#        44            75.500000
#        45            69.333333
#        46            39.500000
#        47            76.750000
# ...

# %%
#agg
cust.groupby('Age')

# %%
cust.groupby(['Gender','Age'])[['Annual Income (k$)']].mean()
cust.groupby('Age').agg({'Annual Income (k$)':['mean',min,max]})
# Out:
#     Annual Income (k$)
#                   mean min  max
# Age
# 18           51.250000  33   65
# 19           57.000000  15   81
# 20           41.600000  16   73
# 21           38.800000  15   62
# 22           31.333333  17   57
# 23           41.500000  16   70
# 24           39.250000  20   60
# 25           57.666667  24   77
# 26           58.000000  54   62
# 27           63.166667  40   88
# 28           85.250000  76  101
# 29           63.600000  28   98
# 30           76.142857  19  137
# 31           48.375000  17   81
# 32           87.181818  48  137
# 33           80.333333  42  113
# 34           79.000000  58  103
# 35           46.666667  18  120
# 36           81.000000  37  103
# 37           65.000000  20   97
# 38           74.500000  54  113
# 39           72.666667  69   78
# 40           61.666667  29   87
# 41          101.000000  99  103
# 42           60.000000  34   86
# 43           65.666667  48   78
# 44           75.500000  73   78
# ...

# %%
cust[cust.Age==18]
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 33           34    Male   18                  33                      92
# 65           66    Male   18                  48                      59
# 91           92    Male   18                  59                      41
# 114         115  Female   18                  65                      48

# %%
#count vs value_count
cust['Gender'].count()
# Out:
# 200

# %%
cust['Gender'].value_counts()
# Out:
# Female    112
# Male       88
# Name: Gender, dtype: int64

# %%
device=pd.read_csv(r"D:\marlabs\Week1\Lesson3\Datasets\user_device.csv")

# %%
device.head()
# Out:
#    use_id  user_id platform  platform_version     device  use_type_id
# 0   22782    26980      ios              10.2  iPhone7,2            2
# 1   22783    29628  android               6.0    Nexus 5            3
# 2   22784    28473  android               5.1   SM-G903F            1
# 3   22785    15200      ios              10.2  iPhone7,2            3
# 4   22786    28239  android               6.0  ONE E1003            1

# %%
usage=pd.read_csv(r"D:\marlabs\Week1\Lesson3\Datasets\user_usage.csv")

# %%
usage.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792

# %%
result=pd.merge(device,usage,on="use_id")

# %%
result.head()
# Out:
#    use_id  user_id platform  platform_version    device  use_type_id  \
# 0   22787    12921  android               4.3  GT-I9505            1
# 1   22788    28714  android               6.0  SM-G930F            1
# 2   22789    28714  android               6.0  SM-G930F            1
# 3   22790    29592  android               5.1     D2303            1
# 4   22792    28217  android               5.1  SM-G361F            1
#
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb
# 0                    21.97                    4.82     1557.33
# 1                  1710.08                  136.88     7267.55
# 2                  1710.08                  136.88     7267.55
# 3                    94.46                   35.17      519.12
# 4                    71.59                   79.26     1557.33

# %%
usage.shape
# Out:
# (240, 4)

# %%
device.shape
# Out:
# (272, 6)

# %%
left_df=pd.merge(usage,device,on='use_id',how='left')

# %%
left_df.shape
# Out:
# (240, 9)

# %%
right_df=pd.merge(usage,device,on='use_id',how='right')

# %%
right_df.shape
# Out:
# (272, 9)

# %%
usage['use_id'].isin(device['use_id']).value_counts()
# Out:
# True     159
# False     81
# Name: use_id, dtype: int64

# %%
usage['use_id'].isin(device['use_id']).count()
# Out:
# 240

# %%
result1=pd.merge(usage,device,on='use_id',how='outer')

# %%
result1.head(1)
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
#
#    user_id platform  platform_version    device  use_type_id
# 0  12921.0  android               4.3  GT-I9505          1.0

# %%
result1.groupby('platform').agg({"outgoing_mins_per_month":"mean",
                                "monthly_mb":[min,max],
                                "use_id":"count"})
# Out:
#          outgoing_mins_per_month monthly_mb           use_id
#                             mean        min       max  count
# platform
# android               201.258535       0.00  31146.67    184
# ios                   366.060000     650.92   1271.39     88

# %%
result1.agg({"outgoing_mins_per_month":"mean",
                                "monthly_mb":[min,max],
                                "use_id":"count"})
# Out:
#        outgoing_mins_per_month  monthly_mb  use_id
# count                      NaN         NaN   353.0
# max                        NaN    31146.67     NaN
# mean                274.559167         NaN     NaN
# min                        NaN        0.00     NaN

# %%
import os
from bs4 import BeautifulSoup

# %%
name=[]
sentence=[]

# %%
for filename in os.listdir("D:\marlabs\Week1\Lesson3\Datasets\corpus"):
    print(filename)
# Out:
# 06_1.xml
# 06_11.xml
# 06_3.xml
# 06_4.xml
# 06_6.xml
# 06_7.xml
# 06_8.xml
# 06_9.xml

# %%
sentence
# Out:
# []

# %%
for filename in os.listdir("D:\marlabs\Week1\Lesson3\Datasets\corpus"):
    with open("D:\marlabs\Week1\Lesson3\Datasets\corpus/"+filename,encoding="ISO-8859-1")as fp:
        soup=BeautifulSoup(fp,"xml")
    name_text=soup.find_all("name")
    name.append(name_text)
    
    sentence_text=soup.find_all("sentence")
    sentence.append(sentence_text)

# %%
name
# Out:
# [[<name>Sharman Networks Ltd v Universal Music Australia Pty Ltd [2006] FCA 1 (5 January 2006)</name>],
#  [<name>Australian Liquor, Hospitality and Miscellaneous Workers Union v Prestige Property Services Pty Ltd [2006] FCA 11 (23 January 2006)</name>],
#  [<name>SZAIX v Minister for Immigration &amp; Multicultural &amp; Indigenous Affairs [2006] FCA 3 (10 January 2006)</name>],
#  [<name>QAAI v Minister for Immigration and Multicultural and Indigenous Affairs [2006] FCA 4 (10 January 2006)</name>],
#  [<name>Comcare v Christina Foster [2006] FCA 6 (12 January 2006)</name>],
#  [<name>Communications, Electrical, Electronic, Energy, Information, Postal, Plumbing &amp; Allied Services Union of Australia v ACI Operations Pty Ltd [2006] FCA 7 (16 January 2006)</name>],
#  [<name>WorldAudio Limited v Australian Communications and Media Authority [2006] FCA 8 (16 January 2006)</name>],
#  [<name>Commissioner of Taxation v Hornibrook [2006] FCA 9 (20 January 2006)</name>]]

# %%
sentence
# Out:
# [[<sentence id="s0">
#    Background to the current application
#
#   1 The applicants Sharman Networks Ltd ('Sharman Networks'), Sharman License Holdings Ltd ('Sharman License') and Ms Nicola Anne Hemming ('Ms Hemming') are each the subject of asset preservation orders made by Wilcox J on 22 March 2005 ('the Mareva orders').</sentence>,
#   <sentence id="s1">When referring to the applicants generally, I will do so as 'the Sharman applicants'.</sentence>,
#   <sentence id="s2">Each of the Sharman applicants was one of ten respondents to infringement of copyright proceedings brought by the present respondents ('the Music companies') in respect of the operation of what was described by the parties as the 'Kazaa system' ('the primary proceedings').</sentence>,
# ...

# %%
data=pd.DataFrame({"name":name,"sentence":sentence})

# %%
data.to_csv("hi.csv")

# %%
pd.read_csv("hi.csv")
# Out:
#    Unnamed: 0                                               name  \
# 0           0  [<name>Sharman Networks Ltd v Universal Music ...
# 1           1  [<name>Australian Liquor, Hospitality and Misc...
# 2           2  [<name>SZAIX v Minister for Immigration &amp; ...
# 3           3  [<name>QAAI v Minister for Immigration and Mul...
# 4           4  [<name>Comcare v Christina Foster [2006] FCA 6...
# 5           5  [<name>Communications, Electrical, Electronic,...
# 6           6  [<name>WorldAudio Limited v Australian Communi...
# 7           7  [<name>Commissioner of Taxation v Hornibrook [...
#
#                                             sentence
# 0  [<sentence id="s0">\r\n Background to the curr...
# 1  [<sentence id="s0">\r\n The nature of the proc...
# 2  [<sentence id="s0">\r\n Introduction \r\n \r\n...
# 3  [<sentence id="s0">\r\n BACKGROUND \r\n The Ba...
# 4  [<sentence id="s0">\r\n THE APPLICATION \r\n \...
# 5  [<sentence id="s0">\r\n \r\n1 On 18 November 2...
# ...
